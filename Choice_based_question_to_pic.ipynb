# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\Unitn\\Lab of Customer and bussiness\\project\\1st.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0  respID  qID  altID  obsID  profileID  vCPU  RAM  Disk  Traffic  \
# 0           1       1    1      1      1        265     2   16    20       20
# 1           2       1    1      2      1        316    16   16   360       20
# 2           3       1    1      3      1        229     2    8   160       30
#
#    Price
# 0     10
# 1     10
# 2      8

# %%
len(df)/3
# Out:
# 10.0

# %%
df1 =df.copy(deep=True)
for i in range(10):
    df_temp = df1.head(3)
    df1.drop(df1.head(3).index, inplace=True)
    cpu1 = str(df_temp['vCPU'][0])
    cpu2 = str(df_temp['vCPU'][1])
    cpu3 = str(df_temp['vCPU'][2])
    ram1 = str(df_temp['RAM'][0])
    ram2 = str(df_temp['RAM'][1])
    ram3 = str(df_temp['RAM'][2])
    disk1 = str(df_temp['Disk'][0])
    disk2 = str(df_temp['Disk'][1])
    disk3 = str(df_temp['Disk'][2])
    traf1 = str(df_temp['Traffic'][0])
    traf2 = str(df_temp['Traffic'][1])
    traf3 = str(df_temp['Traffic'][2])
    price1 = str(df_temp['Price'][0])
    price2 = str(df_temp['Price'][1])
    price3 = str(df_temp['Price'][2])
    question = str(df_temp['respID'][0])+'.'+str(df_temp['qID'][0])
    break

# %%
from PIL import Image, ImageDraw, ImageFont
img = Image.new('RGB', (420, 260), color = 'white')
# font = ImageFont.load('C:\\Windows\\Fonts\\Arial\\ARIALN.TTF')
font = ImageFont.truetype(font='C:\\Windows\\Fonts\\Arial\\arial.ttf', size=12)
fontB = ImageFont.truetype(font='C:\\Windows\\Fonts\\Arial\\arialbd.ttf', size=15)



d = ImageDraw.Draw(img)
line1 = [(100, 35), (100,240)]
line2 = [(200, 35), (200,240)]
line3 = [(300, 35), (300,240)]
line4 = [(400, 35), (400,240)]
d.line(line1, fill ="gray", width = 1)
d.line(line2, fill ="gray", width = 1)
d.line(line3, fill ="gray", width = 1)
d.line(line4, fill ="gray", width = 1)

# Features
d.text((40,60), "vCPU", fill=(0,0,0) , font=font)
d.text((40,100), "Ram", fill=(0,0,0) , font=font)
d.text((40,140), "Disk", fill=(0,0,0) , font=font)
d.text((40,180), "Traffic", fill=(0,0,0) , font=font)
d.text((40,220), "Price", fill=(0,0,0) , font=font)

# Options
d.text((120,20), "Option 1", fill=(0,0,0) , font=fontB)
d.text((220,20), "Option 2", fill=(0,0,0) , font=fontB)
d.text((320,20), "Option 3", fill=(0,0,0) , font=fontB)


# numbers of option 1
d.text((150,60), cpu1 , fill=(0,0,0) , font=fontB)
d.text((150,100), ram1 , fill=(0,0,0) , font=fontB)
d.text((150,140), disk1 , fill=(0,0,0) , font=fontB)
d.text((150,180), traf1 , fill=(0,0,0) , font=fontB)
d.text((150,220), price1 , fill=(0,0,0) , font=fontB)

# numbers of option 2
d.text((250,60), cpu2 , fill=(0,0,0) , font=fontB)
d.text((250,100), ram2 , fill=(0,0,0) , font=fontB)
d.text((250,140), disk2 , fill=(0,0,0) , font=fontB)
d.text((250,180), traf2 , fill=(0,0,0) , font=fontB)
d.text((250,220), price2 , fill=(0,0,0) , font=fontB)

# numbers of option 3
d.text((350,60), cpu3 , fill=(0,0,0) , font=fontB)
d.text((350,100), ram3 , fill=(0,0,0) , font=fontB)
d.text((350,140), disk3 , fill=(0,0,0) , font=fontB)
d.text((350,180), traf3 , fill=(0,0,0) , font=fontB)
d.text((350,220), price3 , fill=(0,0,0) , font=fontB)
img.save('D:\\Unitn\\Lab of Customer and bussiness\\project\\qpic\\'+question+'.jpg')

# %%
import pandas as pd
from PIL import Image, ImageDraw, ImageFont
df = pd.read_csv('D:\\Unitn\\Lab of Customer and bussiness\\project\\questions.csv')
df1 =df.copy(deep=True)
for i in range(int(len(df)/3)):
    df_temp = df1.head(3)
    df_temp = df_temp.reset_index(drop=True)
#     print(df_temp)
    cpu1 = str(df_temp['vCPU'][0])
    cpu2 = str(df_temp['vCPU'][1])
    cpu3 = str(df_temp['vCPU'][2])
    ram1 = str(df_temp['RAM'][0])
    ram2 = str(df_temp['RAM'][1])
    ram3 = str(df_temp['RAM'][2])
    disk1 = str(df_temp['Disk'][0])
    disk2 = str(df_temp['Disk'][1])
    disk3 = str(df_temp['Disk'][2])
    traf1 = str(df_temp['Traffic'][0])
    traf2 = str(df_temp['Traffic'][1])
    traf3 = str(df_temp['Traffic'][2])
    price1 = str(df_temp['Price'][0])
    price2 = str(df_temp['Price'][1])
    price3 = str(df_temp['Price'][2])
    question = str(df_temp['respID'][0])+'.'+str(df_temp['qID'][0])
    df1.drop(df1.head(3).index, inplace=True)
    
    img = Image.new('RGB', (420, 260), color = 'white')
    # font = ImageFont.load('C:\\Windows\\Fonts\\Arial\\ARIALN.TTF')
    font = ImageFont.truetype(font='C:\\Windows\\Fonts\\Arial\\arial.ttf', size=12)
    fontB = ImageFont.truetype(font='C:\\Windows\\Fonts\\Arial\\arialbd.ttf', size=15)



    d = ImageDraw.Draw(img)
    line1 = [(100, 35), (100,240)]
    line2 = [(200, 35), (200,240)]
    line3 = [(300, 35), (300,240)]
    line4 = [(400, 35), (400,240)]
    d.line(line1, fill ="gray", width = 1)
    d.line(line2, fill ="gray", width = 1)
    d.line(line3, fill ="gray", width = 1)
    d.line(line4, fill ="gray", width = 1)

    # Features
    d.text((40,60), "vCPU", fill=(0,0,0) , font=font)
    d.text((40,100), "Ram", fill=(0,0,0) , font=font)
    d.text((40,140), "Disk", fill=(0,0,0) , font=font)
    d.text((40,180), "Traffic", fill=(0,0,0) , font=font)
    d.text((40,220), "Price", fill=(0,0,0) , font=font)

    # Options
    d.text((120,20), "Option 1", fill=(0,0,0) , font=fontB)
    d.text((220,20), "Option 2", fill=(0,0,0) , font=fontB)
    d.text((320,20), "Option 3", fill=(0,0,0) , font=fontB)


    # numbers of option 1
    d.text((150,60), cpu1 , fill=(0,0,0) , font=fontB)
    d.text((150,100), ram1 , fill=(0,0,0) , font=fontB)
    d.text((150,140), disk1 , fill=(0,0,0) , font=fontB)
    d.text((150,180), traf1 , fill=(0,0,0) , font=fontB)
    d.text((150,220), price1 , fill=(0,0,0) , font=fontB)

    # numbers of option 2
    d.text((250,60), cpu2 , fill=(0,0,0) , font=fontB)
    d.text((250,100), ram2 , fill=(0,0,0) , font=fontB)
    d.text((250,140), disk2 , fill=(0,0,0) , font=fontB)
    d.text((250,180), traf2 , fill=(0,0,0) , font=fontB)
    d.text((250,220), price2 , fill=(0,0,0) , font=fontB)

    # numbers of option 3
    d.text((350,60), cpu3 , fill=(0,0,0) , font=fontB)
    d.text((350,100), ram3 , fill=(0,0,0) , font=fontB)
    d.text((350,140), disk3 , fill=(0,0,0) , font=fontB)
    d.text((350,180), traf3 , fill=(0,0,0) , font=fontB)
    d.text((350,220), price3 , fill=(0,0,0) , font=fontB)
    img.save('D:\\Unitn\\Lab of Customer and bussiness\\project\\qpic\\'+question+'.jpg')
